# %% [markdown]
# # Scoring Publishers

# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML

# %matplotlib inline

# %% [markdown]
# Use the preprocessed combined dataset provided by Cody.

# %%
filenames = ["./11_14_combined", "./11_15_combined", "./11_16_combined",
             "./11_17_combined", "./11_18_combined", "./11_19_combined"]
df = pd.concat([pd.read_json(fname, lines=True) for fname in filenames])

# %% [markdown]
# Unfortunately, there are only 2 unique publishers for this collection of hours.

# %%
print(df.pub_network_id.unique())
df.head()
# Out:
# [767 727]
#    ad_network_id  ad_type  advertiser_id bid_requests bid_responses  c_cnt  \
# 0           1839  [story]           4523           []            []    0.0
# 1           1839  [story]           4523           []            []    0.0
# 2           1839  [story]           4523           []            []    0.0
# 3           1839  [story]           4523           []            []    0.0
# 4           1845  [story]           5125           []            []    0.0
#
#   c_timestamp  c_txn_fee  c_txn_rate  campaign_id   ...   txn_fee  txn_rate  \
# 0         NaN        NaN         NaN        26027   ...       NaN       NaN
# 1         NaN        NaN         NaN        26027   ...       NaN       NaN
# 2         NaN        NaN         NaN        26027   ...       NaN       NaN
# 3         NaN        NaN         NaN        26027   ...       NaN       NaN
# 4         NaN        NaN         NaN        25924   ...       NaN       NaN
#
#    ua_device  ua_device_type        ua_name   ua_os_name vi_cnt  vi_timestamp  \
# 0      Other              PC          Opera  Windows 8.1    0.0           NaN
# 1      Other              PC         Chrome    Windows 7    0.0           NaN
# 2      Other              PC             IE    Windows 7    0.0           NaN
# 3     iPhone             MOB  Mobile Safari          iOS    0.0           NaN
# 4       iPad             TAB  Mobile Safari          iOS    0.0           NaN
#
#   vv_cnt zone_id
# 0    0.0   17681
# 1    0.0   26024
# 2    0.0   26024
# 3    0.0   26024
# 4    0.0   26024
#
# [5 rows x 42 columns]

# %% [markdown]
# Select the appropriate features we want to use to score publishers.

# %%
#Also have 'vi_flag_cnt' and 'c_flag_cnt', but are often NaN for all columns
pub_df = df.loc[:,['advertiser_id', 'site_id', 'zone_id','pub_network_id', 'vi_cnt', 'i_cnt', 'c_cnt', 
                   'ua_device_type', 'ua_name']]
pub_df.shape
# Out:
# (1529033, 9)

# %% [markdown]
# Drop all of the rows with any null value.

# %%
cleaned_pub_df = pub_df.dropna(axis=0)
print(cleaned_pub_df.shape)
cleaned_pub_df.head()
# Out:
# (1224812, 9)
#    advertiser_id  site_id  zone_id  pub_network_id  vi_cnt  i_cnt  c_cnt  \
# 0           4523    12760    17681             767     0.0    1.0    0.0
# 1           4523    13042    26024             767     0.0    1.0    0.0
# 2           4523    13042    26024             767     0.0    1.0    0.0
# 3           4523    13042    26024             767     0.0    1.0    0.0
# 4           5125    13042    26024             767     0.0    1.0    0.0
#
#   ua_device_type        ua_name
# 0             PC          Opera
# 1             PC         Chrome
# 2             PC             IE
# 3            MOB  Mobile Safari
# 4            TAB  Mobile Safari

# %%
cleaned_pub_df.pub_network_id.unique()
# Out:
# array([767, 727])

# %% [markdown]
# Read in the lookup tables provided by Polymorph. 'site_id_map' is a mapping from site_id to domain name. 'pub_network_id_map' is a mapping from pub_network_id to publisher name. 'advertiser_id_map' is a mapping from advertiser_id to advertiser name.

# %%
site_id_df = pd.read_json('./site_id_map.json')
display(site_id_df.head())

pub_network_id_df = pd.read_json('./pub_network_id_map.json')
display(pub_network_id_df.head())

advertiser_id_df = pd.read_json('./advertiser_id_map.json')
display(advertiser_id_df.head())
# Out:
#                  domain  site_id
# 0              \t https    24631
# 1       centredaily.com     4784
# 2   ledger-enquirer.com     4777
# 3       mcclatchydc.com     4774
# 4      newsobserver.com     4770
#       pub_network_dynamic  pub_network_id    publisher_name
# 0       614 -  Liquor.com             614        Liquor.com
# 1     594 - 121 Marketing             594     121 Marketing
# 2  603 - 121Marketing.com             603  121Marketing.com
# 3         458 - 183 Media             458         183 Media
# 4      481 - 1WorldOnline             481      1WorldOnline
#    advertiser_id           advertiser_name
# 0           4212       Yandex LLC - Direct
# 1           2011  , Muncie Power Products'
# 2           1952                     . PHD
# 3           2677                 1043 Labs
# 4           4372             10amazing.com

# %% [markdown]
# Since there are only two publishers, we decided to aggregate counts over advertisers instead. This just adds relevant metrics such as c_cnt/i_cnt, which is the ratio of clicks to impressions.

# %%
grouped_advertisers = cleaned_pub_df.groupby('advertiser_id')['c_cnt','vi_cnt','i_cnt'].sum()

grouped_advertisers['num_ads'] = cleaned_pub_df.groupby('advertiser_id').size()
grouped_advertisers['vi_cnt/num_ads'] = grouped_advertisers['vi_cnt']/grouped_advertisers['num_ads']
grouped_advertisers['i_cnt/num_ads'] = grouped_advertisers['i_cnt']/grouped_advertisers['num_ads']
grouped_advertisers['vi_cnt/i_cnt'] = grouped_advertisers['vi_cnt']/grouped_advertisers['i_cnt']
grouped_advertisers['c_cnt/vi_cnt'] = grouped_advertisers['c_cnt']/grouped_advertisers['vi_cnt']
grouped_advertisers['c_cnt/i_cnt'] = grouped_advertisers['c_cnt']/grouped_advertisers['i_cnt']
grouped_advertisers['c_cnt/num_ads'] = grouped_advertisers['c_cnt']/grouped_advertisers['num_ads']

grouped_advertisers.reset_index(inplace=True)
grouped_advertisers = pd.merge(grouped_advertisers, advertiser_id_df, how='left', on='advertiser_id')
grouped_advertisers.dropna(inplace=True)

grouped_advertisers.sort_values('c_cnt/num_ads', ascending=0)
# Out:
#     advertiser_id  c_cnt   vi_cnt     i_cnt  num_ads  vi_cnt/num_ads  \
# 23           5152  245.0  24793.0   29417.0    29548        0.839075
# 17           5063  153.0  17656.0   21322.0    21411        0.824623
# 25           5189   24.0   3628.0    4276.0     4292        0.845294
# 2            2917  116.0    303.0   96541.0    96610        0.003136
# 19           5118   26.0   2150.0   53417.0    53491        0.040194
# 13           4514    3.0    550.0    6500.0     6507        0.084524
# 15           4539   13.0   3523.0   28551.0    28583        0.123255
# 20           5125  104.0  10691.0  297818.0   298104        0.035863
# 3            2998    4.0   2176.0   13755.0    13805        0.157624
# 16           4974    2.0   1823.0    6971.0     6983        0.261063
# 8            3689    4.0    640.0   14351.0    14354        0.044587
# 9            3842   48.0      3.0  182884.0   182889        0.000016
# 22           5140    3.0     86.0   11986.0    11987        0.007174
# 24           5178    2.0   1894.0   12073.0    12082        0.156762
# 6            3672    5.0  15052.0   34313.0    34359        0.438080
# 14           4523   50.0  18545.0  394383.0   394667        0.046989
# 5            3575    1.0   3714.0    9134.0     9144        0.406168
# 18           5084    0.0      5.0    2606.0     2618        0.001910
# 10           4033    0.0      8.0      17.0       17        0.470588
# 21           5129    0.0      1.0      40.0       40        0.025000
# 7            3680    0.0   1222.0    2026.0     2029        0.602267
# 4            3572    0.0      7.0     206.0      206        0.033981
# 1            2788    0.0     23.0      82.0       82        0.280488
#
#     i_cnt/num_ads  vi_cnt/i_cnt  c_cnt/vi_cnt  c_cnt/i_cnt  c_cnt/num_ads  \
# 23       0.995567      0.842812      0.009882     0.008329       0.008292
# 17       0.995843      0.828065      0.008666     0.007176       0.007146
# 25       0.996272      0.848457      0.006615     0.005613       0.005592
# 2        0.999286      0.003139      0.382838     0.001202       0.001201
# 19       0.998617      0.040249      0.012093     0.000487       0.000486
# 13       0.998924      0.084615      0.005455     0.000462       0.000461
# 15       0.998880      0.123393      0.003690     0.000455       0.000455
# 20       0.999041      0.035898      0.009728     0.000349       0.000349
# 3        0.996378      0.158197      0.001838     0.000291       0.000290
# 16       0.998282      0.261512      0.001097     0.000287       0.000286
# 8        0.999791      0.044596      0.006250     0.000279       0.000279
# 9        0.999973      0.000016     16.000000     0.000262       0.000262
# 22       0.999917      0.007175      0.034884     0.000250       0.000250
# 24       0.999255      0.156879      0.001056     0.000166       0.000166
# 6        0.998661      0.438668      0.000332     0.000146       0.000146
# 14       0.999280      0.047023      0.002696     0.000127       0.000127
# 5        0.998906      0.406613      0.000269     0.000109       0.000109
# 18       0.995416      0.001919      0.000000     0.000000       0.000000
# 10       1.000000      0.470588      0.000000     0.000000       0.000000
# 21       1.000000      0.025000      0.000000     0.000000       0.000000
# 7        0.998521      0.603159      0.000000     0.000000       0.000000
# 4        1.000000      0.033981      0.000000     0.000000       0.000000
# 1        1.000000      0.280488      0.000000     0.000000       0.000000
#
#               advertiser_name
# 23                   Facebook
# 17                 Chase Bank
# 25             JPMorgan Chase
# 2   Health Sciences Institute
# 19      I Got Your Back Pains
# 13                    Paravex
# 15                         EZ
# 20         Good Men On The Go
# 3                  FetchaRate
# 16                       Paco
# 8                     Newsmax
# 9          So Much Confidence
# 22                    eminata
# 24            Finance Journal
# 6                   Gundry MD
# 14                          T
# 5                    arpintec
# 18            Talk Tech Daily
# 10          Brain Pills Today
# 21              Margaux Salon
# 7                Viral Online
# 4                       Alena
# 1                   megaxport

# %% [markdown]
# This is a grouping of publishers in the same fashion as with advertisers, but yields only two rows since there are only two publishers in our data.

# %%
grouped_publishers = cleaned_pub_df.groupby('pub_network_id')['c_cnt','vi_cnt','i_cnt'].sum()

grouped_publishers['num_ads'] = cleaned_pub_df.groupby('pub_network_id').size()
grouped_publishers['vi_cnt/num_ads'] = grouped_publishers['vi_cnt']/grouped_publishers['num_ads']
grouped_publishers['i_cnt/num_ads'] = grouped_publishers['i_cnt']/grouped_publishers['num_ads']
grouped_publishers['vi_cnt/i_cnt'] = grouped_publishers['vi_cnt']/grouped_publishers['i_cnt']
grouped_publishers['c_cnt/vi_cnt'] = grouped_publishers['c_cnt']/grouped_publishers['vi_cnt']
grouped_publishers['c_cnt/i_cnt'] = grouped_publishers['c_cnt']/grouped_publishers['i_cnt']
grouped_publishers['c_cnt/num_ads'] = grouped_publishers['c_cnt']/grouped_publishers['num_ads']
grouped_publishers.reset_index(inplace=True)
grouped_publishers = pd.merge(grouped_publishers, pub_network_id_df, how='left', on='pub_network_id')
grouped_publishers.dropna(inplace=True)

grouped_publishers.sort_values('c_cnt/i_cnt', ascending=0)
grouped_publishers
# Out:
#    pub_network_id  c_cnt   vi_cnt      i_cnt  num_ads  vi_cnt/num_ads  \
# 0             727  422.0  46077.0    55015.0    55251        0.833958
# 1             767  381.0  62416.0  1168658.0  1169561        0.053367
#
#    i_cnt/num_ads  vi_cnt/i_cnt  c_cnt/vi_cnt  c_cnt/i_cnt  c_cnt/num_ads  \
# 0       0.995729      0.837535      0.009159     0.007671       0.007638
# 1       0.999228      0.053408      0.006104     0.000326       0.000326
#
#   pub_network_dynamic publisher_name
# 0        727 - Pocket         Pocket
# 1       767 - Newsmax        Newsmax

# %% [markdown]
# This isn't really enough data to provide a useful feature, so instead I ran a script over the all the polymorph data to aggregate counts grouped by publisher, then advertiser, then ua_device_type, with the associated publisher and advertiser names added as columns.

# %%
grouped_cnts_df = pd.read_pickle('grouped_cnts.pkl.gz', compression='gzip')
grouped_cnts_df.sort_values('c_cnt', ascending=0)
# Out:
#      pub_network_id  advertiser_id ua_device_type   c_cnt    vi_cnt  \
# 5               727           5152            MOB  1934.0  216406.0
# 86              767           4701             PC  1185.0    8702.0
# 6               727           5152             PC   884.0  157478.0
# 94              767           4923            TAB   839.0   41966.0
# 7               727           5152            TAB   825.0   59046.0
# 52              767           3672            TAB   670.0    3019.0
# 98              767           4986             PC   663.0  372663.0
# 92              767           4923            MOB   533.0   99082.0
# 10              727           5189             PC   507.0  141056.0
# 30              767           2917            TAB   506.0    1473.0
# 117             767           5125            TAB   347.0   17753.0
# 9               727           5189            MOB   280.0   37772.0
# 13              767           2732            MOB   205.0     832.0
# 2               727           5063            MOB   202.0   27520.0
# 78              767           4523             PC   180.0  197027.0
# 116             767           5125             PC   173.0   29342.0
# 77              767           4523            MOB   155.0   69060.0
# 4               727           5063            TAB   145.0    9437.0
# 11              727           5189            TAB   144.0   11806.0
# 29              767           2917             PC   142.0    2756.0
# 3               727           5063             PC   118.0   17035.0
# 65              767           3842            MOB    86.0      21.0
# 113             767           5118            TAB    70.0     449.0
# 14              767           2732             PC    66.0   36122.0
# 99              767           4986            TAB    62.0    3170.0
# 66              767           3842             PC    54.0       3.0
# 58              767           3689             PC    53.0   26136.0
# 115             767           5125            MOB    44.0    8374.0
# 17              767           2746            MOB    43.0    1713.0
# 130             767           5187            MOB    42.0    1322.0
# ..              ...            ...            ...     ...       ...
# 102             767           5084             PC     0.0      14.0
# 69              767           4064            MOB     0.0       0.0
# 87              767           4739            BOT     0.0       0.0
# 74              767           4514             PC     0.0       2.0
# 68              767           4033             PC     0.0      34.0
# 76              767           4523            BOT     0.0       0.0
# 67              767           3927             PC     0.0       0.0
# 1               727           5063            BOT     0.0       0.0
# 79              767           4523            TAB     0.0       0.0
# 64              767           3842            BOT     0.0       0.0
# 63              767           3717            TAB     0.0     146.0
# 62              767           3717             PC     0.0       2.0
# 83              767           4559            BOT     0.0       0.0
# 85              767           4701            BOT     0.0       0.0
# 60              767           3717            BOT     0.0       0.0
# 56              767           3689            BOT     0.0       0.0
# 40              767           3574             PC     0.0       1.0
# 89              767           4739             PC     0.0       0.0
# 54              767           3680            MOB     0.0       1.0
# 91              767           4923            BOT     0.0       0.0
# 53              767           3680            BOT     0.0       0.0
# 93              767           4923             PC     0.0       3.0
# 49              767           3672            BOT     0.0       0.0
# 47              767           3597            BOT     0.0       0.0
# 96              767           4986            BOT     0.0       0.0
# 46              767           3587            TAB     0.0       0.0
# 42              767           3575            BOT     0.0       0.0
# 41              767           3574            TAB     0.0      49.0
# 100             767           5084            BOT     0.0       0.0
# 0               338           5165             PC     0.0       1.0
#
#          i_cnt          publisher_name            advertiser_name
# 5     259580.0                  Pocket                   Facebook
# 86   1494382.0                 Newsmax            Whatfinger News
# 6     177526.0                  Pocket                   Facebook
# 94   1571401.0                 Newsmax                 Accelleral
# 7      76417.0                  Pocket                   Facebook
# 52    563610.0                 Newsmax                  Gundry MD
# 98   3236620.0                 Newsmax                Hemp Relief
# 92   4523979.0                 Newsmax                 Accelleral
# 10    156716.0                  Pocket             JPMorgan Chase
# 30    381196.0                 Newsmax  Health Sciences Institute
# 117   399124.0                 Newsmax         Good Men On The Go
# 9      46125.0                  Pocket             JPMorgan Chase
# 13    686492.0                 Newsmax                  Affiliati
# 2      33396.0                  Pocket                 Chase Bank
# 78   1625520.0                 Newsmax                          T
# 116   230750.0                 Newsmax         Good Men On The Go
# 77   2166400.0                 Newsmax                          T
# 4      12766.0                  Pocket                 Chase Bank
# 11     15641.0                  Pocket             JPMorgan Chase
# 29    170706.0                 Newsmax  Health Sciences Institute
# 3      18906.0                  Pocket                 Chase Bank
# 65    380470.0                 Newsmax         So Much Confidence
# 113    65420.0                 Newsmax      I Got Your Back Pains
# 14    128208.0                 Newsmax                  Affiliati
# 99    111155.0                 Newsmax                Hemp Relief
# 66    198752.0                 Newsmax         So Much Confidence
# 58    272213.0                 Newsmax                    Newsmax
# 115   405338.0                 Newsmax         Good Men On The Go
# 17    336766.0                 Newsmax              InsiderBeauty
# 130   124580.0                 Newsmax                       Skin
# ..         ...                     ...                        ...
# 102      358.0                 Newsmax            Talk Tech Daily
# 69         4.0                 Newsmax              Heart Healthy
# 87         0.0                 Newsmax                 Gossip Tab
# 74         2.0                 Newsmax                    Paravex
# 68        59.0                 Newsmax          Brain Pills Today
# 76         0.0                 Newsmax                          T
# 67         9.0                 Newsmax                        Max
# 1          0.0                  Pocket                 Chase Bank
# 79         8.0                 Newsmax                          T
# 64         0.0                 Newsmax         So Much Confidence
# 63      1277.0                 Newsmax                 mylife.com
# 62         2.0                 Newsmax                 mylife.com
# 83         0.0                 Newsmax           MedJournalOnline
# 85         0.0                 Newsmax            Whatfinger News
# 60         0.0                 Newsmax                 mylife.com
# 56         0.0                 Newsmax                    Newsmax
# 40        17.0                 Newsmax              Mike Ducheine
# 89         6.0                 Newsmax                 Gossip Tab
# 54       417.0                 Newsmax               Viral Online
# 91         0.0                 Newsmax                 Accelleral
# 53         0.0                 Newsmax               Viral Online
# 93       869.0                 Newsmax                 Accelleral
# 49         0.0                 Newsmax                  Gundry MD
# 47         0.0                 Newsmax                         me
# 96         0.0                 Newsmax                Hemp Relief
# 46         1.0                 Newsmax        Digital Media World
# 42         0.0                 Newsmax                   arpintec
# 41       381.0                 Newsmax              Mike Ducheine
# 100        0.0                 Newsmax            Talk Tech Daily
# 0          2.0  Demo AdsNative Network                 CyberMoney
#
# [133 rows x 8 columns]

# %% [markdown]
# All the unique advertisers over the whole dataset with at least 1 nonnull click count, vi count, and i count.

# %%
grouped_cnts_df.loc[:,'advertiser_name'].unique()
# Out:
# array(['CyberMoney', 'Chase Bank', 'Facebook', 'JPMorgan Chase',
#        'Affiliati', 'InsiderBeauty', 'NewRetirement', 'Julie H',
#        'megaxport', 'Health Sciences Institute', 'FetchaRate', 'Alena',
#        'Mike Ducheine', 'arpintec', 'Digital Media World', 'me',
#        'Gundry MD', 'Viral Online', 'Newsmax', 'mylife.com',
#        'So Much Confidence', 'Max', 'Brain Pills Today', 'Heart Healthy',
#        'Smarter Consumer Tips', 'Paravex', 'T', 'EZ', 'MedJournalOnline',
#        'Whatfinger News', 'Gossip Tab', 'Accelleral', 'Paco',
#        'Hemp Relief', 'Talk Tech Daily', 'Weekly National',
#        'Absolute Viral News', 'I Got Your Back Pains',
#        'Good Men On The Go', 'Margaux Salon', 'eminata', 'Finance Journal',
#        'Skin'], dtype=object)

# %% [markdown]
# We can then use the aggregated counts to make add featuers such as click-to-impression ratio, which will be the average over the entire dataset and thus a useful classification for a given auction.
